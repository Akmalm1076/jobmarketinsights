# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load datasets from the data/ folder
benefits = pd.read_csv("../data/benefits.csv")
company_industries = pd.read_csv("../data/company_industries.csv")
company_specialities = pd.read_csv("../data/company_specialities.csv")
employee_counts = pd.read_csv("../data/employee_counts.csv")
job_industries = pd.read_csv("../data/job_industries.csv")


# Quick look at the shape of each dataset
print("Job Postings shape:", job_postings.shape)
print("Companies shape:", companies.shape)
print("Job Skills shape:", job_skills.shape)
# Out:
# Job Postings shape: (15886, 27)
# Companies shape: (6063, 10)
# Job Skills shape: (27899, 2)

# %%
# Display first 5 rows
print(job_postings.head())
print(companies.head())
print(job_skills.head())
# Out:
#       job_id  company_id                     title  \
# 0   85008768         NaN  Licensed Insurance Agent
# 1  133114754  77766802.0             Sales Manager
# 2  133196985   1089558.0        Model Risk Auditor
# 3  381055942  96654609.0          Business Manager
# 4  529257371   1244539.0       NY Studio Assistant
#
#                                          description  max_salary  med_salary  \
# 0  While many industries were hurt by the last fe...     52000.0         NaN
# 1  Are you a dynamic and creative marketing profe...         NaN         NaN
# 2  Join Us as a Model Risk Auditor – Showcase You...         NaN         NaN
# 3  Business ManagerFirst Baptist Church ForneyFor...         NaN         NaN
# 4  YOU COULD BE ONE OF THE MAGIC MAKERS\nKen Fulk...         NaN         NaN
#
#    min_salary pay_period formatted_work_type           location  ...  \
# 0     45760.0     YEARLY           Full-time          Chico, CA  ...
# ...

# %%
# Example visualization: Top 10 job titles
top_jobs = job_postings['title'].value_counts().head(10)
top_jobs.plot(kind='bar', figsize=(10,6), color='skyblue')
plt.title("Top 10 Job Titles")
plt.xlabel("Job Title")
plt.ylabel("Count")
plt.show()

# %%
print("job_postings:", job_postings.columns.tolist())
print("companies:", companies.columns.tolist())
print("job_skills:", job_skills.columns.tolist())
print("benefits:", benefits.columns.tolist())
print("company_industries:", company_industries.columns.tolist())
print("company_specialities:", company_specialities.columns.tolist())
print("employee_counts:", employee_counts.columns.tolist())
print("job_industries:", job_industries.columns.tolist())
# Out:
# job_postings: ['job_id', 'company_id', 'title', 'description', 'max_salary', 'med_salary', 'min_salary', 'pay_period', 'formatted_work_type', 'location', 'applies', 'original_listed_time', 'remote_allowed', 'views', 'job_posting_url', 'application_url', 'application_type', 'expiry', 'closed_time', 'formatted_experience_level', 'skills_desc', 'listed_time', 'posting_domain', 'sponsored', 'work_type', 'currency', 'compensation_type']
# companies: ['company_id', 'name', 'description', 'company_size', 'state', 'country', 'city', 'zip_code', 'address', 'url']
# job_skills: ['job_id', 'skill_abr']
# benefits: ['job_id', 'inferred', 'type']
# company_industries: ['company_id', 'industry']
# company_specialities: ['company_id', 'speciality']
# employee_counts: ['company_id', 'employee_count', 'follower_count', 'time_recorded']
# job_industries: ['job_id', 'industry_id']
